# %%
from lens import *
from gr import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
f2 = Flashlight(0, 3/2 * 8, 0, 3, 15)
g2 = SchwarzschildGravitizerSpherical(0,0,0,8)
sim2 = Simulator(f2,g2)

# %%
sim2.evolve(100,0.1)

# %%
sim2.draw()

# %%
f3 = Flashlight(0, 3/2 * 8, 0, 3, 15)
g3 = KerrGravitizer(0,0,0,8,0.1)
sim3 = Simulator(f3,g3)

# %%
sim3.evolve(100,0.1)

# %%
sim3.draw()

# %%
f2 = Flashlight(0, 3/2 * 8, 0, 3, 15)
g2 = SchwarzschildGravitizerSpherical(0,0,0,8)
sim2 = Simulator(f2,g2)

# %%
sim2.evolve(100,1)

# %%
sim2.draw()

# %%
f = Flashlight(0, 3/2 * 8, 0, 3, 15)
g = KerrGravitizer(0,0,0,8,0.0)
sim = Simulator(f,g)

# %%
sim.evolve(100,1)

# %%
sim.draw()

# %%
f = Flashlight(0, 3/2 * 8, 0, 3, 15, 0, 90)
g = KerrGravitizer(0,0,0,8,0.5)
sim = Simulator(f,g)

# %%
sim.evolve(100,1)

# %%
sim.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f = Flashlight(0, 3/2 * 8, 0, 3, 15)
g = KerrGravitizer(0,0,0,8,5)
sim = Simulator(f,g)

# %%
sim.evolve(100,1)

# %%
sim.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f = Flashlight(0, 3/2 * 8, 0, 3, 15)
g = KerrGravitizer(0,0,0,8,64*0.98)
sim = Simulator(f,g)

# %%
sim.evolve(100,1)

# %%
sim.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f = Flashlight(0, 10, 0, 1, 15, 0)
g = KerrGravitizer(0,0,0,8,5)
sim = Simulator(f,g)

# %%
sim.evolve(100,1)

# %%
sim.draw(threeD=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = radius*1.1*np.cos(phi*np.pi/180)
    y = radius*1.1*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,0)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)
    x = radius*1.1*np.cos(phi*np.pi/180)
    y = radius*1.1*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,0.5)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = radius*1.1*np.cos(phi*np.pi/180)
    y = radius*1.1*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,1)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = radius*1.1*np.cos(phi*np.pi/180)
    y = radius*1.1*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,radius)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = radius*1.1*np.cos(phi*np.pi/180)
    y = radius*1.1*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,radius**2 * 0.98)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %% [markdown]
# It turns out sending all the light rays inward looks more intuitive...

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,0)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,0.5)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,1)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,radius)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,radius**2 * 0.98)
sim = Simulator(flash_list,g)

# %%
sim.evolve(100,1)

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
# f = Flashlight(0, 8.5, 0, 1, 15, 90)
flash_list = []
radius = 8
n_rays = 8
for i in range(n_rays):
    phi = (360/n_rays * i)    
    x = -radius*2*np.cos(phi*np.pi/180)
    y = -radius*2*np.sin(phi*np.pi/180)
    flash_list.append(Flashlight(x, y, 0, 1, 0, phi))
g = KerrGravitizer(0,0,0,radius,radius**2)
sim = Simulator(flash_list,g)

# %%
sim.evolve(200,1)

# %% [markdown]
# This looks the coolest to me

# %%
# %matplotlib inline
sim.draw(threeD=False)

# %%
g.metric.christoffels
# Out:
# {(1, 0, 0): 4.0/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1,
#   1,
#   1): 0.5*r**2*(2*r - 8 - 512.0*cos(th)**2/r**3)/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1, 2, 2): -1.0*r**3/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1,
#   3,
#   3): -0.5*r**2*(2*r - 2048.0*sin(th)**2/r**2)*sin(th)**2/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1, 0, 1): 0,
#  (1, 0, 2): 0,
#  (1,
#   0,
#   3): -128.0*sin(th)**2/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1,
#   1,
#   2): -256.0*sin(th)*cos(th)/(1.0*r**4 - 8.0*r**3 + 256.0*r**2 + 256.0*cos(th)**2),
#  (1, 1, 3): 0,
#  (1, 2, 3): 0,
#  (2, 0, 0): -256.0*sin(th)*cos(th)/(r**2 + 256.0*cos(th)**2),
#  (2, 1, 1): 256.0*sin(th)*cos(th)/(r**2*(r**2 + 256.0*cos(th)**2)),
#  (2, 2, 2): -256.0*sin(th)*cos(th)/(r**2 + 256.0*cos(th)**2),
#  (2,
#   3,
# ...

# %%
f4 = Flashlight(0, -3/2 * 8, 0, 3, 15,0,90)
g4 = KerrGravitizer(0,0,0,8,5)
sim4 = Simulator(f4,g4)

# %%
sim4.evolve(100,1)

# %%
sim4.draw()

# %%
g4.metric.metric
# Out:
# Matrix([
# [          -1.5625*cos(th)**2 - 1 + 8/r,                                            0,                        0,                             -1.5625*cos(th)**2 - 20.0*sin(th)**2/r],
# [                                     0, r**2 - 8*r + 1.5625 + 1.5625*cos(th)**2/r**2,                        0,                                                                  0],
# [                                     0,                                            0, r**2 + 1.5625*cos(th)**2,                                                                  0],
# [-1.5625*cos(th)**2 - 20.0*sin(th)**2/r,                                            0,                        0, (r**2 + 1.5625*cos(th)**2 + 1.5625 + 12.5*sin(th)**2/r)*sin(th)**2]])
